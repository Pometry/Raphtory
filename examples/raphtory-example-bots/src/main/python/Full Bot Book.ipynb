# %%
import networkx as nx
from pymotif import Motif
import pandas as pd 
import datetime
import pytz
import os
import matplotlib
import matplotlib.pyplot as plt
import scipy
import jellyfish
import difflib
import networkx as nx
# import raphtoryclient 
from pymotif import Motif
import pyvis
from pyvis.network import Network
import matplotlib.pyplot as plt
import numpy as np
import string
import pydot
import seaborn as sns
import graphviz
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score
from sklearn.metrics import PrecisionRecallDisplay

import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import re

from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential, load_model

import pickle

from sklearn.feature_extraction.text import TfidfVectorizer

import string
nltk.download('wordnet') # first-time use only
nltk.download('omw-1.4')
from tqdm import tqdm


import sys 
print(sys.version)
# Out:
# 3.10.5 (main, Jun 23 2022, 17:15:32) [Clang 13.0.0 (clang-1300.0.29.30)]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bensteer/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/bensteer/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/bensteer/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
data = pd.read_csv("1423.csv")
data
# Out:
# /var/folders/g0/9w1p6w5120556qmxhks7lc8c0000gn/T/ipykernel_18393/1096453207.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("1423.csv")
#                  Tweet Created At  Tweet By Handle               Source  \
# 0       2022-03-08 23:56:13+00:00  MustafiMohamme1  Twitter for Android
# 1       2022-03-08 23:55:57+00:00        CrowYusuf      Twitter Web App
# 2       2022-03-08 23:53:51+00:00        alendales  Twitter for Android
# 3       2022-03-08 23:53:49+00:00     Shandaren123      Twitter Web App
# 4       2022-03-08 23:52:49+00:00    Betty69319283  Twitter for Android
# ...                           ...              ...                  ...
# 235238  2022-03-01 16:42:08+00:00         LordEnyo  Twitter for Android
# 235239  2022-03-01 16:41:39+00:00  Free_Libyan2022      Twitter Web App
# 235240  2022-03-01 16:41:32+00:00         Aman_SA_  Twitter for Android
# 235241  2022-03-01 16:41:26+00:00        Aschrafie      Twitter Web App
# 235242  2022-03-01 16:40:30+00:00      BabingtonCo   Twitter for iPhone
#
#         Likes Count  Retweets Count  Quotes Count  Comments Count  \
# 0                 0               0             0               0
# 1                 2               1             0               0
# 2                 0               0             0               0
# 3                 0               0             0               0
# 4                 0               0             0               0
# ...             ...             ...           ...             ...
# 235238            0               0             0               0
# 235239            0               0             0               0
# 235240            0               0             0               0
# 235241            0               0             0               0
# 235242            1               0             0               0
#
#                            Tweet Mentions  \
# 0                             sanusi90064
# 1                           justsomeguycc
# 2                                   5thSu
# 3                           Gpkumarreddy2
# 4       WHO;Ukraine;Tati_Ethiopia;teodros
# ...                                   ...
# 235238                                NaN
# 235239                        abiuradimeh
# 235240                    KremlinRussia_E
# 235241                         eleven45pm
# 235242                                NaN
#
#                                            Tweet Hashtags Tweet Symbols  ...  \
# 0         IStandWithPutin;istandwithrussia;iSupportRussia           NaN  ...
# 1                        IStandWithPutin;IStandWithRussia           NaN  ...
# 2                          Russia;Russian;IStandWithPutin           NaN  ...
# 3                        IStandWithPutin;istandwithrussia           NaN  ...
# 4                                                     NaN           NaN  ...
# ...                                                   ...           ...  ...
# 235238         FuckPutin;PutinWarCriminal;IStandWithPutin           NaN  ...
# 235239            Russia;IStandWithPutin;istandwithrussia           NaN  ...
# 235240  USA;Putin;UkraineRussiaWar;IStandWithPutin;Ukr...           NaN  ...
# 235241                                                NaN           NaN  ...
# 235242  evil;IStandWithPutin;IStandWithUkraine;DefeatP...           NaN  ...
#
#         Profile Country                                           User URL  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 235238              NaN                    https://lordenyo.newgrounds.com
# 235239              NaN                https://twitter.com/Free_Libyan2022
# 235240            India  https://www.instagram.com/invites/contact/?i=1...
# 235241              NaN                                                NaN
# 235242    United States                               https://Babington.Co
#
#                                          User Description Protected Verified  \
# 0                                       አለማወቁን ያወቀ አዋቂ ነው     False    False
# 1       🇮🇹 Pronouns: Screw SJWs/Screw Puritans\n\nAlte...     False    False
# 2       Из дворян...\nИз крестьян...\nИз рабочих...\nИ...     False    False
# 3       Just another russian bot... maybe, hard to tel...     False    False
# 4                                                politics     False    False
# ...                                                   ...       ...      ...
# 235238  29 years old. Him/He. BLM! Video games, table ...     False    False
# 235239            #IStandWithRussia #IStandWithPutin\n 💪✌     False    False
# 235240  #शिव_ही_सत्य_है\n\nhttps://secret.viralsachxd....     False    False
# 235241                                                NaN     False    False
# 235242  I’d love to design a magnificent book from you...     False    False
#
#        Followers Count Following Count  User Listed Count  \
# 0                   56             137                  0
# 1                   59             126                  1
# 2                 1143             214                 18
# 3                   23              17                  0
# 4                 3150            1229                  3
# ...                ...             ...                ...
# 235238             133            4417                  1
# 235239            1075            1067                  1
# 235240             403             719                  0
# 235241             222             386                  0
# 235242            1974            1853                 62
#
#         User Favourites Count User Statuses Count
# 0                        1949                 658
# 1                        2898                4197
# 2                       43182              112201
# 3                        6843                 672
# 4                       15727               22120
# ...                       ...                 ...
# 235238                  60068               33275
# 235239                 173048               92465
# 235240                  34731                8042
# 235241                  14479                3041
# 235242                  10445                6965
#
# [235243 rows x 42 columns]

# %%
data.rename(columns={"Tweet Created At" : "created_at", "Retweeted User" : "in_reply_to_user_id", "Tweet By Handle" : "author_id", "Full Text" : "text", "Retweets Count" : "retweet_count", "Likes Count" : "like_count", "Source" : "source", "Tweet Hashtags" : "hashtags", "Tweet Mentions" : "user_mentions", "Tweet Symbols" : "symbols", "Reported Language" : "lang"}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235243 entries, 0 to 235242
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   created_at                235243 non-null  object
#  1   author_id                 235243 non-null  object
#  2   source                    235243 non-null  object
#  3   like_count                235243 non-null  int64
#  4   retweet_count             235243 non-null  int64
#  5   Quotes Count              235243 non-null  int64
#  6   Comments Count            235243 non-null  int64
#  7   user_mentions             203191 non-null  object
#  8   hashtags                  178006 non-null  object
#  9   symbols                   11 non-null      object
#  10  Tweet Poll                0 non-null       float64
#  11  in_reply_to_user_id       190101 non-null  object
#  12  Original Tweet Link       190101 non-null  object
#  13  text                      235243 non-null  object
#  14  Retweet Full Text         190101 non-null  object
#  15  Tweet URLs in Text        10747 non-null   object
#  16  Tweet Media in Text       75188 non-null   object
#  17  Is Retweet                235243 non-null  bool
#  18  Is Quote Status           235243 non-null  bool
#  19  Tweet Status Link         235243 non-null  object
#  20  lang                      235243 non-null  object
#  21  Tweet Lat                 1 non-null       float64
#  22  Tweet Long                1 non-null       float64
#  23  Tweet Associated Country  748 non-null     object
#  24  Tweet Associated Place    749 non-null     object
#  25  User Id                   235243 non-null  object
#  26  User Handle               235243 non-null  object
#  27  User Name                 235236 non-null  object
#  28  User Created At           235243 non-null  object
#  29  User Location             129345 non-null  object
#  30  Profile Lat               100270 non-null  float64
#  31  Profile Long              100270 non-null  float64
#  32  Profile Country           100224 non-null  object
#  33  User URL                  30450 non-null   object
#  34  User Description          177101 non-null  object
#  35  Protected                 235243 non-null  bool
#  36  Verified                  235243 non-null  bool
#  37  Followers Count           235243 non-null  int64
#  38  Following Count           235243 non-null  int64
#  39  User Listed Count         235243 non-null  int64
#  40  User Favourites Count     235243 non-null  int64
#  41  User Statuses Count       235243 non-null  int64
# dtypes: bool(4), float64(5), int64(9), object(24)
# memory usage: 69.1+ MB

# %%
client_tweets = data[["author_id", "created_at", "in_reply_to_user_id", "lang", "retweet_count", "like_count", "source", "text", "hashtags", "user_mentions"]].copy()

# %%
client_tweets
# Out:
#               author_id                 created_at in_reply_to_user_id lang  \
# 0       MustafiMohamme1  2022-03-08 23:56:13+00:00         sanusi90064   en
# 1             CrowYusuf  2022-03-08 23:55:57+00:00                 NaN  und
# 2             alendales  2022-03-08 23:53:51+00:00               5thSu   en
# 3          Shandaren123  2022-03-08 23:53:49+00:00       Gpkumarreddy2   en
# 4         Betty69319283  2022-03-08 23:52:49+00:00       Tati_Ethiopia   am
# ...                 ...                        ...                 ...  ...
# 235238         LordEnyo  2022-03-01 16:42:08+00:00                 NaN   en
# 235239  Free_Libyan2022  2022-03-01 16:41:39+00:00         abiuradimeh   it
# 235240         Aman_SA_  2022-03-01 16:41:32+00:00                 NaN  und
# 235241        Aschrafie  2022-03-01 16:41:26+00:00          eleven45pm   en
# 235242      BabingtonCo  2022-03-01 16:40:30+00:00                 NaN   en
#
#         retweet_count  like_count               source  \
# 0                   0           0  Twitter for Android
# 1                   1           2      Twitter Web App
# 2                   0           0  Twitter for Android
# 3                   0           0      Twitter Web App
# 4                   0           0  Twitter for Android
# ...               ...         ...                  ...
# 235238              0           0  Twitter for Android
# 235239              0           0      Twitter Web App
# 235240              0           0  Twitter for Android
# 235241              0           0      Twitter Web App
# 235242              0           1   Twitter for iPhone
#
#                                                      text  \
# 0       RT @sanusi90064: Iraq, Baghdad\n#iSupportRussi...
# 1       @justsomeguycc #IStandWithRussia #IStandWithPutin
# 2       RT @5thSu: Good Afternoon Friends..😍🇷🇺💪❤️🌹\n#I...
# 3       RT @Gpkumarreddy2: usa and nato hypocrites    ...
# 4       RT @Tati_Ethiopia: የምዕራባውያን አሽከር የሆነው @WHO &am...
# ...                                                   ...
# 235238  If anyone here supports Putin, please, make th...
# 235239  RT @abiuradimeh: Le girandole dell'amore\n#ist...
# 235240  @KremlinRussia_E \n\n#IndiaStandWithPutin \n#I...
# 235241  RT @eleven45pm: Putin was on the ground in Afr...
# 235242  All who tweet #IStandWithPutin are standing wi...
#
#                                                  hashtags  \
# 0         IStandWithPutin;istandwithrussia;iSupportRussia
# 1                        IStandWithPutin;IStandWithRussia
# 2                          Russia;Russian;IStandWithPutin
# 3                        IStandWithPutin;istandwithrussia
# 4                                                     NaN
# ...                                                   ...
# 235238         FuckPutin;PutinWarCriminal;IStandWithPutin
# 235239            Russia;IStandWithPutin;istandwithrussia
# 235240  USA;Putin;UkraineRussiaWar;IStandWithPutin;Ukr...
# 235241                                                NaN
# 235242  evil;IStandWithPutin;IStandWithUkraine;DefeatP...
#
#                             user_mentions
# 0                             sanusi90064
# 1                           justsomeguycc
# 2                                   5thSu
# 3                           Gpkumarreddy2
# 4       WHO;Ukraine;Tati_Ethiopia;teodros
# ...                                   ...
# 235238                                NaN
# 235239                        abiuradimeh
# 235240                    KremlinRussia_E
# 235241                         eleven45pm
# 235242                                NaN
#
# [235243 rows x 10 columns]

# %%
def split_list(lst):
    if lst == "":
        return []
    else:
        return lst.split(";")

# %%
client_tweets["hashtags"] = client_tweets["hashtags"].astype("string")
client_tweets["hashtags"] = client_tweets["hashtags"].fillna("")
client_tweets["hashtags"] = client_tweets["hashtags"].apply(lambda x: split_list(x))

# %%
client_tweets["hashtags_count"]=client_tweets["hashtags"].apply(lambda x:len(x))

# %%
client_tweets["user_mentions"] = client_tweets["user_mentions"].astype("string")
client_tweets["user_mentions"] = client_tweets["user_mentions"].fillna("")
client_tweets["user_mentions"] = client_tweets["user_mentions"].apply(lambda x: split_list(x))

# %%
client_tweets["user_mentions_count"]=client_tweets["user_mentions"].apply(lambda x:len(x))

# %%
client_tweets = client_tweets[(client_tweets['lang']=='en')|(client_tweets['lang']=='und')]

client_tweets
# Out:
#               author_id                 created_at in_reply_to_user_id lang  \
# 0       MustafiMohamme1  2022-03-08 23:56:13+00:00         sanusi90064   en
# 1             CrowYusuf  2022-03-08 23:55:57+00:00                 NaN  und
# 2             alendales  2022-03-08 23:53:51+00:00               5thSu   en
# 3          Shandaren123  2022-03-08 23:53:49+00:00       Gpkumarreddy2   en
# 5        ALICIA56483057  2022-03-08 23:52:42+00:00     worldobserver33  und
# ...                 ...                        ...                 ...  ...
# 235237        hbarjunky  2022-03-01 16:43:28+00:00                 NaN   en
# 235238         LordEnyo  2022-03-01 16:42:08+00:00                 NaN   en
# 235240         Aman_SA_  2022-03-01 16:41:32+00:00                 NaN  und
# 235241        Aschrafie  2022-03-01 16:41:26+00:00          eleven45pm   en
# 235242      BabingtonCo  2022-03-01 16:40:30+00:00                 NaN   en
#
#         retweet_count  like_count               source  \
# 0                   0           0  Twitter for Android
# 1                   1           2      Twitter Web App
# 2                   0           0  Twitter for Android
# 3                   0           0      Twitter Web App
# 5                   0           0  Twitter for Android
# ...               ...         ...                  ...
# 235237              0           1            TweetDeck
# 235238              0           0  Twitter for Android
# 235240              0           0  Twitter for Android
# 235241              0           0      Twitter Web App
# 235242              0           1   Twitter for iPhone
#
#                                                      text  \
# 0       RT @sanusi90064: Iraq, Baghdad\n#iSupportRussi...
# 1       @justsomeguycc #IStandWithRussia #IStandWithPutin
# 2       RT @5thSu: Good Afternoon Friends..😍🇷🇺💪❤️🌹\n#I...
# 3       RT @Gpkumarreddy2: usa and nato hypocrites    ...
# 5       RT @worldobserver33: #IStandWithPutin #istandw...
# ...                                                   ...
# 235237  @Mann_mit_Hund @de_rt_com Dr. Gideon Polya cou...
# 235238  If anyone here supports Putin, please, make th...
# 235240  @KremlinRussia_E \n\n#IndiaStandWithPutin \n#I...
# 235241  RT @eleven45pm: Putin was on the ground in Afr...
# 235242  All who tweet #IStandWithPutin are standing wi...
#
#                                                  hashtags  \
# 0       [IStandWithPutin, istandwithrussia, iSupportRu...
# 1                     [IStandWithPutin, IStandWithRussia]
# 2                      [Russia, Russian, IStandWithPutin]
# 3                     [IStandWithPutin, istandwithrussia]
# 5       [RussianUkrainianWar, IStandWithPutin, istandw...
# ...                                                   ...
# 235237                                  [IStandWithPutin]
# 235238     [FuckPutin, PutinWarCriminal, IStandWithPutin]
# 235240  [USA, Putin, UkraineRussiaWar, IStandWithPutin...
# 235241                                                 []
# 235242  [evil, IStandWithPutin, IStandWithUkraine, Def...
#
#                      user_mentions  hashtags_count  user_mentions_count
# 0                    [sanusi90064]               3                    1
# 1                  [justsomeguycc]               2                    1
# 2                          [5thSu]               3                    1
# 3                  [Gpkumarreddy2]               2                    1
# 5                [worldobserver33]               3                    1
# ...                            ...             ...                  ...
# 235237  [de_rt_com, Mann_mit_Hund]               1                    2
# 235238                          []               3                    0
# 235240           [KremlinRussia_E]               6                    1
# 235241                [eleven45pm]               0                    1
# 235242                          []               4                    0
#
# [225359 rows x 12 columns]

# %%
data.rename(columns={"created_at" : "tweet_created_at", "User Created At" : "created_at", "User Description" : "description", "author_id" : "id", "Profile Country" : "location", "User Name" : "name", "Followers Count" : "followers_count", "Following Count" : "following_count", "User Listed Count" : "listed_count", "User URL" : "url", "User Handle" : "username", "Verified" : "verified"}, inplace=True)

# %%
client_users = data[["created_at", "description", "id", "location", "name", "followers_count", "following_count", "listed_count", "url", "username", "verified"]].copy()

# %%
tweet_no = client_users["id"].value_counts().to_frame()
tweet_no.reset_index(inplace=True)
tweet_no.columns = ["id","tweet_count"]
tweet_no
# Out:
#                     id  tweet_count
# 0      PardipK23979889          655
# 1            tindian88          606
# 2        scarryghost40          478
# 3      Free_Libyan2022          467
# 4      divinityofblaze          412
# ...                ...          ...
# 93480           hypple            1
# 93481      dvduadotcom            1
# 93482     Emperor_kins            1
# 93483    abbah_makarfi            1
# 93484      BabingtonCo            1
#
# [93485 rows x 2 columns]

# %%
client_users.drop_duplicates(inplace=True)
client_users.reset_index(inplace=True)
client_users
# Out:
#         index                 created_at  \
# 0           0  2021-08-28 19:10:25+00:00
# 1           1  2020-11-10 21:14:01+00:00
# 2           2  2010-09-08 00:20:35+00:00
# 3           3  2022-03-07 00:06:01+00:00
# 4           4  2021-02-03 18:10:48+00:00
# ...       ...                        ...
# 93480  235226  2021-02-18 08:38:41+00:00
# 93481  235227  2012-07-08 01:47:01+00:00
# 93482  235228  2022-02-01 04:15:12+00:00
# 93483  235235  2017-06-24 08:33:00+00:00
# 93484  235242  2011-02-11 00:59:16+00:00
#
#                                              description               id  \
# 0                                      አለማወቁን ያወቀ አዋቂ ነው  MustafiMohamme1
# 1      🇮🇹 Pronouns: Screw SJWs/Screw Puritans\n\nAlte...        CrowYusuf
# 2      Из дворян...\nИз крестьян...\nИз рабочих...\nИ...        alendales
# 3      Just another russian bot... maybe, hard to tel...     Shandaren123
# 4                                               politics    Betty69319283
# ...                                                  ...              ...
# 93480  Anti-social\nMechanical engineering (Trailers)...       DoumDoum19
# 93481  ذندگی کے دو ہی اصول  ☝🏻الله اور ان کا۔ رسول  ص...      XtasyRehman
# 93482                                                NaN      BinduHamal3
# 93483                                                NaN  RomeoMakgaleme1
# 93484  I’d love to design a magnificent book from you...      BabingtonCo
#
#             location                                              name  \
# 0                NaN                   Mustafi MohammedAmin 🇪🇹🇪🇷🇩🇯🇸🇴🇰🇪
# 1                NaN  Yusuf-Pronouns: No Puritans/No SJWs #KenAkamatsu
# 2                NaN                                 Александр Шаталов
# 3                NaN                                         Shandaren
# 4                NaN                                       BettyTerefe
# ...              ...                                               ...
# 93480            NaN                                         Doum_Doum
# 93481  United States                                           HRehman
# 93482            NaN                                       Bindu Hamal
# 93483   South Africa                                 Romeo Makgalemela
# 93484  United States                                      Babington.Co
#
#        followers_count  following_count  listed_count                   url  \
# 0                   56              137             0                   NaN
# 1                   59              126             1                   NaN
# 2                 1143              214            18                   NaN
# 3                   23               17             0                   NaN
# 4                 3150             1229             3                   NaN
# ...                ...              ...           ...                   ...
# 93480               72               45             0                   NaN
# 93481              196              459             0                   NaN
# 93482                1                9             0                   NaN
# 93483               12               81             0                   NaN
# 93484             1974             1853            62  https://Babington.Co
#
#               username  verified
# 0      MustafiMohamme1     False
# 1            CrowYusuf     False
# 2            alendales     False
# 3         Shandaren123     False
# 4        Betty69319283     False
# ...                ...       ...
# 93480       DoumDoum19     False
# 93481      XtasyRehman     False
# 93482      BinduHamal3     False
# 93483  RomeoMakgaleme1     False
# 93484      BabingtonCo     False
#
# [93485 rows x 12 columns]

# %%
client_users = pd.merge(client_users, tweet_no, on="id")
client_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93485 entries, 0 to 93484
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            93485 non-null  int64
#  1   created_at       93485 non-null  object
#  2   description      73011 non-null  object
#  3   id               93485 non-null  object
#  4   location         43216 non-null  object
#  5   name             93479 non-null  object
#  6   followers_count  93485 non-null  int64
#  7   following_count  93485 non-null  int64
#  8   listed_count     93485 non-null  int64
#  9   url              13204 non-null  object
#  10  username         93485 non-null  object
#  11  verified         93485 non-null  bool
#  12  tweet_count      93485 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 9.4+ MB

# %% [markdown]
# # Getting Sentiment

# %%
OUTPUT_SENTIMENT ="sentiment.csv"
OUTPUT_LABELS = "nlp_labelled.csv"
MAX_SEQUENCE_LENGTH = 30

# %%
model = load_model("best_model.hdf5")
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
# Out:
# 2022-07-26 17:51:28.364137: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
stop_words = stopwords.words('english')
stemmer = SnowballStemmer('english')

text_cleaning_re = "rt|rt@\S+|@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# %%
def preprocess(text, stem=False):
    text = re.sub(text_cleaning_re, ' ', str(text).lower()).strip()
    text = re.sub("istandwithputin", "i stand with putin", text)
    text = re.sub("istandwithrussia", "i stand with russia", text)
    text = re.sub("isupportrussia", "i support russia", text)
    text = re.sub("istandwithzelensky", "i stand with zelensky", text)
    text = re.sub("fuckputin", "fuck putin", text)
    text = re.sub("putinwarcriminal", "putin war criminal", text)
    tokens = []
    for token in text.split():
        if token not in stop_words:
            if stem:
                tokens.append(stemmer.stem(token))
            else:
                tokens.append(token)
    return " ".join(tokens)

# %%
def decode_sentiment(score):
    if score>0.6:
        return "Positive"
    elif score<0.4:
        return "Negative"
    else:
        return "Neutral"

# %%
client_tweets.dropna(subset=["author_id", "text"], inplace=True)
client_tweets
# Out:
# /var/folders/g0/9w1p6w5120556qmxhks7lc8c0000gn/T/ipykernel_18393/3160366657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   client_tweets.dropna(subset=["author_id", "text"], inplace=True)
#               author_id                 created_at in_reply_to_user_id lang  \
# 0       MustafiMohamme1  2022-03-08 23:56:13+00:00         sanusi90064   en
# 1             CrowYusuf  2022-03-08 23:55:57+00:00                 NaN  und
# 2             alendales  2022-03-08 23:53:51+00:00               5thSu   en
# 3          Shandaren123  2022-03-08 23:53:49+00:00       Gpkumarreddy2   en
# 5        ALICIA56483057  2022-03-08 23:52:42+00:00     worldobserver33  und
# ...                 ...                        ...                 ...  ...
# 235237        hbarjunky  2022-03-01 16:43:28+00:00                 NaN   en
# 235238         LordEnyo  2022-03-01 16:42:08+00:00                 NaN   en
# 235240         Aman_SA_  2022-03-01 16:41:32+00:00                 NaN  und
# 235241        Aschrafie  2022-03-01 16:41:26+00:00          eleven45pm   en
# 235242      BabingtonCo  2022-03-01 16:40:30+00:00                 NaN   en
#
#         retweet_count  like_count               source  \
# 0                   0           0  Twitter for Android
# 1                   1           2      Twitter Web App
# 2                   0           0  Twitter for Android
# 3                   0           0      Twitter Web App
# 5                   0           0  Twitter for Android
# ...               ...         ...                  ...
# 235237              0           1            TweetDeck
# 235238              0           0  Twitter for Android
# 235240              0           0  Twitter for Android
# 235241              0           0      Twitter Web App
# 235242              0           1   Twitter for iPhone
#
#                                                      text  \
# 0       RT @sanusi90064: Iraq, Baghdad\n#iSupportRussi...
# 1       @justsomeguycc #IStandWithRussia #IStandWithPutin
# 2       RT @5thSu: Good Afternoon Friends..😍🇷🇺💪❤️🌹\n#I...
# 3       RT @Gpkumarreddy2: usa and nato hypocrites    ...
# 5       RT @worldobserver33: #IStandWithPutin #istandw...
# ...                                                   ...
# 235237  @Mann_mit_Hund @de_rt_com Dr. Gideon Polya cou...
# 235238  If anyone here supports Putin, please, make th...
# 235240  @KremlinRussia_E \n\n#IndiaStandWithPutin \n#I...
# 235241  RT @eleven45pm: Putin was on the ground in Afr...
# 235242  All who tweet #IStandWithPutin are standing wi...
#
#                                                  hashtags  \
# 0       [IStandWithPutin, istandwithrussia, iSupportRu...
# 1                     [IStandWithPutin, IStandWithRussia]
# 2                      [Russia, Russian, IStandWithPutin]
# 3                     [IStandWithPutin, istandwithrussia]
# 5       [RussianUkrainianWar, IStandWithPutin, istandw...
# ...                                                   ...
# 235237                                  [IStandWithPutin]
# 235238     [FuckPutin, PutinWarCriminal, IStandWithPutin]
# 235240  [USA, Putin, UkraineRussiaWar, IStandWithPutin...
# 235241                                                 []
# 235242  [evil, IStandWithPutin, IStandWithUkraine, Def...
#
#                      user_mentions  hashtags_count  user_mentions_count
# 0                    [sanusi90064]               3                    1
# 1                  [justsomeguycc]               2                    1
# 2                          [5thSu]               3                    1
# 3                  [Gpkumarreddy2]               2                    1
# 5                [worldobserver33]               3                    1
# ...                            ...             ...                  ...
# 235237  [de_rt_com, Mann_mit_Hund]               1                    2
# 235238                          []               3                    0
# 235240           [KremlinRussia_E]               6                    1
# 235241                [eleven45pm]               0                    1
# 235242                          []               4                    0
#
# [225359 rows x 12 columns]

# %%
puretext = client_tweets[["author_id", "text"]].copy()
puretext.dropna(inplace=True)
puretext
# Out:
#               author_id                                               text
# 0       MustafiMohamme1  RT @sanusi90064: Iraq, Baghdad\n#iSupportRussi...
# 1             CrowYusuf  @justsomeguycc #IStandWithRussia #IStandWithPutin
# 2             alendales  RT @5thSu: Good Afternoon Friends..😍🇷🇺💪❤️🌹\n#I...
# 3          Shandaren123  RT @Gpkumarreddy2: usa and nato hypocrites    ...
# 5        ALICIA56483057  RT @worldobserver33: #IStandWithPutin #istandw...
# ...                 ...                                                ...
# 235237        hbarjunky  @Mann_mit_Hund @de_rt_com Dr. Gideon Polya cou...
# 235238         LordEnyo  If anyone here supports Putin, please, make th...
# 235240         Aman_SA_  @KremlinRussia_E \n\n#IndiaStandWithPutin \n#I...
# 235241        Aschrafie  RT @eleven45pm: Putin was on the ground in Afr...
# 235242      BabingtonCo  All who tweet #IStandWithPutin are standing wi...
#
# [225359 rows x 2 columns]

# %%
puretext.text = puretext.text.apply(lambda x: preprocess(x))

# %%
x = pad_sequences(tokenizer.texts_to_sequences(puretext.text), maxlen = MAX_SEQUENCE_LENGTH)

# %%
scores = model.predict(x, verbose=1, batch_size=10000)
y_pred_1d = [decode_sentiment(score) for score in scores]
# Out:
# 23/23 [==============================] - 23s 939ms/step

# %%
client_tweets["sentiment_score"] = scores
client_tweets["sentiment"] = y_pred_1d
client_tweets = client_tweets.drop('text',axis=1)
client_tweets = client_tweets.drop('hashtags',axis=1)
client_tweets = client_tweets.drop('user_mentions',axis=1)
client_tweets
# Out:
# /var/folders/g0/9w1p6w5120556qmxhks7lc8c0000gn/T/ipykernel_18393/11955189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   client_tweets["sentiment_score"] = scores
# /var/folders/g0/9w1p6w5120556qmxhks7lc8c0000gn/T/ipykernel_18393/11955189.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   client_tweets["sentiment"] = y_pred_1d
#               author_id                 created_at in_reply_to_user_id lang  \
# 0       MustafiMohamme1  2022-03-08 23:56:13+00:00         sanusi90064   en
# 1             CrowYusuf  2022-03-08 23:55:57+00:00                 NaN  und
# 2             alendales  2022-03-08 23:53:51+00:00               5thSu   en
# 3          Shandaren123  2022-03-08 23:53:49+00:00       Gpkumarreddy2   en
# 5        ALICIA56483057  2022-03-08 23:52:42+00:00     worldobserver33  und
# ...                 ...                        ...                 ...  ...
# 235237        hbarjunky  2022-03-01 16:43:28+00:00                 NaN   en
# 235238         LordEnyo  2022-03-01 16:42:08+00:00                 NaN   en
# 235240         Aman_SA_  2022-03-01 16:41:32+00:00                 NaN  und
# 235241        Aschrafie  2022-03-01 16:41:26+00:00          eleven45pm   en
# 235242      BabingtonCo  2022-03-01 16:40:30+00:00                 NaN   en
#
#         retweet_count  like_count               source  hashtags_count  \
# 0                   0           0  Twitter for Android               3
# 1                   1           2      Twitter Web App               2
# 2                   0           0  Twitter for Android               3
# 3                   0           0      Twitter Web App               2
# 5                   0           0  Twitter for Android               3
# ...               ...         ...                  ...             ...
# 235237              0           1            TweetDeck               1
# 235238              0           0  Twitter for Android               3
# 235240              0           0  Twitter for Android               6
# 235241              0           0      Twitter Web App               0
# 235242              0           1   Twitter for iPhone               4
#
#         user_mentions_count  sentiment_score sentiment
# 0                         1         0.581710   Neutral
# 1                         1         0.834725  Positive
# 2                         1         0.947319  Positive
# 3                         1         0.554189   Neutral
# 5                         1         0.799398  Positive
# ...                     ...              ...       ...
# 235237                    2         0.468949   Neutral
# 235238                    0         0.555652   Neutral
# 235240                    1         0.735688  Positive
# 235241                    1         0.593956   Neutral
# 235242                    0         0.703507  Positive
#
# [225359 rows x 11 columns]

# %%
client_tweets.to_csv(OUTPUT_SENTIMENT, index=False)

# %% [markdown]
# # Raphtory

# %%
from pathlib import Path
from pyraphtory.context import PyRaphtory
from pyraphtory.vertex import Vertex
from pyraphtory.steps import Iterate, Step

import os
import subprocess
import sys

os.environ['defaultLogLevel'] = "DEBUG"

pr = PyRaphtory(spout_input=Path('sentiment.csv'), builder_script=Path('builder.py'),  builder_class='BotsGraphBuilder', mode='batch', logging=True).open()
rg = pr.graph()
# Out:
# b'WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.\n'
# b"18:09:35.333 [io-compute-4] INFO  com.raphtory.spouts.FileSpout - Spout: Processing file 'sentiment.csv' ...\n"
# b'18:09:35.506 [io-compute-4] ERROR com.raphtory.internals.management.Prometheus$ - Failed to start Prometheus on port 9999\n'
# b'18:09:35.519 [io-compute-4] INFO  com.raphtory.internals.management.Prometheus$ - Prometheus started on port /0:0:0:0:0:0:0:0:53978\n'
# b'18:09:36.669 [spawner-akka.actor.default-dispatcher-3] INFO  akka.event.slf4j.Slf4jLogger - Slf4jLogger started\n'
# b"18:09:37.018 [io-compute-4] INFO  com.raphtory.internals.management.PartitionsManager$ - Creating '1' Partition Managers for raphtory_1366537474.\n"
# b"18:09:37.185 [io-compute-2] INFO  com.raphtory.internals.components.partition.LocalBatchHandler - Could not parse: author_id,created_at,in_reply_to_user_id,lang,retweet_count,like_count,source,hashtags_count,user_mentions_count,sentiment_score,sentiment. Fails with exception pemja.core.PythonException: <class 'ValueError'>: Invalid isoformat string: 'created_at'\n"
# b'-7774162037213450504\n'
# b'18:09:37.218 [io-compute-4] INFO  com.raphtory.internals.management.Py4JServer - Starting PythonGatewayServer...\n'
# b'18:09:37.222 [io-compute-4] INFO  com.raphtory.internals.management.Py4JServer - Started PythonGatewayServer on port 53979 host: localhost/127.0.0.1\n'
# b'18:09:37.231 [io-compute-4] INFO  com.raphtory.internals.management.Py4JServer - Writing PythonGatewayServer details to file...\n'
# b'18:09:37.234 [io-compute-4] INFO  com.raphtory.internals.management.Py4JServer - PythonGatewayServer secret - b77efdc70f78d9d6e93dfbf739933820d103f9b32a2464449b949512610165f4\n'

# %%
local_sink = pr.local_sink()

cols = ["inDegree", "outDegree", "degree","triangleCount","prlabel","cclabel","twoHopPaths"]

tracker = rg.at(1646697600)\
            .past()\
            .transform(pr.page_rank())\
            .transform(pr.connected_components())\
            .transform(pr.degree())\
            .transform(pr.two_hops_path(set([])))\
            .transform(pr.local_triangle_count())\
            .select(cols) \
            .write_to(local_sink)\
            .wait_for_job()


pr.results_to_dataframe(local_sink.results(),cols)
# Out:
#         timestamp window             name  inDegree  outDegree  degree  \
# 0      1646697600   None   CrazyDuckPlayz         0          1       1
# 1      1646697600   None  Prayagr47839997         0          1       1
# 2      1646697600   None        Rsbxyz007         0          1       1
# 3      1646697600   None    biswal_shriya         0          0       0
# 4      1646697600   None   AmyWeinstein17         0          1       1
# ...           ...    ...              ...       ...        ...     ...
# 87668  1646697600   None     KnightSirdam         4          0       4
# 87669  1646697600   None    SharonForex21         0          2       2
# 87670  1646697600   None    IAmBilalAbbas         0          1       1
# 87671  1646697600   None          veisuwh         0          7       7
# 87672  1646697600   None  Not_Mo_Tweeting         0          2       2
#
#        triangleCount  prlabel              cclabel  \
# 0                  0  0.15000 -9223236717174605845
# 1                  0  0.15000 -9223236717174605845
# 2                  0  0.15000 -9223236717174605845
# 3                  0  0.15000  8921216852220583009
# 4                  0  0.15000 -9223236717174605845
# ...              ...      ...                  ...
# 87668              0  0.32873 -9223236717174605845
# 87669              0  0.15000 -9223236717174605845
# 87670              0  0.15000 -9223236717174605845
# 87671              2  0.15000 -9223236717174605845
# 87672              0  0.15000 -9223236717174605845
#
#                                              twoHopPaths
# 0      [[NickKnudsenUS, SteveHofstetter], [NickKnudse...
# 1                                                    NaN
# 2                         [[PhlataCaskey, BassilSabelo]]
# 3                                                    NaN
# 4      [[AndrewOnSeeAIR, NickKnudsenUS], [AndrewOnSee...
# ...                                                  ...
# 87668                                                NaN
# 87669                                                NaN
# 87670                                                NaN
# 87671  [[PALLAVI39674211, Sydney_Sidwell], [PALLAVI39...
# 87672                                                NaN
#
# [87673 rows x 10 columns]

# %%
client_tweets
# Out:
#               author_id                 created_at in_reply_to_user_id lang  \
# 0       MustafiMohamme1  2022-03-08 23:56:13+00:00         sanusi90064   en
# 1             CrowYusuf  2022-03-08 23:55:57+00:00                 NaN  und
# 2             alendales  2022-03-08 23:53:51+00:00               5thSu   en
# 3          Shandaren123  2022-03-08 23:53:49+00:00       Gpkumarreddy2   en
# 5        ALICIA56483057  2022-03-08 23:52:42+00:00     worldobserver33  und
# ...                 ...                        ...                 ...  ...
# 235237        hbarjunky  2022-03-01 16:43:28+00:00                 NaN   en
# 235238         LordEnyo  2022-03-01 16:42:08+00:00                 NaN   en
# 235240         Aman_SA_  2022-03-01 16:41:32+00:00                 NaN  und
# 235241        Aschrafie  2022-03-01 16:41:26+00:00          eleven45pm   en
# 235242      BabingtonCo  2022-03-01 16:40:30+00:00                 NaN   en
#
#         retweet_count  like_count               source  \
# 0                   0           0  Twitter for Android
# 1                   1           2      Twitter Web App
# 2                   0           0  Twitter for Android
# 3                   0           0      Twitter Web App
# 5                   0           0  Twitter for Android
# ...               ...         ...                  ...
# 235237              0           1            TweetDeck
# 235238              0           0  Twitter for Android
# 235240              0           0  Twitter for Android
# 235241              0           0      Twitter Web App
# 235242              0           1   Twitter for iPhone
#
#                                                      text  \
# 0       RT @sanusi90064: Iraq, Baghdad\n#iSupportRussi...
# 1       @justsomeguycc #IStandWithRussia #IStandWithPutin
# 2       RT @5thSu: Good Afternoon Friends..😍🇷🇺💪❤️🌹\n#I...
# 3       RT @Gpkumarreddy2: usa and nato hypocrites    ...
# 5       RT @worldobserver33: #IStandWithPutin #istandw...
# ...                                                   ...
# 235237  @Mann_mit_Hund @de_rt_com Dr. Gideon Polya cou...
# 235238  If anyone here supports Putin, please, make th...
# 235240  @KremlinRussia_E \n\n#IndiaStandWithPutin \n#I...
# 235241  RT @eleven45pm: Putin was on the ground in Afr...
# 235242  All who tweet #IStandWithPutin are standing wi...
#
#                                                  hashtags  \
# 0       [IStandWithPutin, istandwithrussia, iSupportRu...
# 1                     [IStandWithPutin, IStandWithRussia]
# 2                      [Russia, Russian, IStandWithPutin]
# 3                     [IStandWithPutin, istandwithrussia]
# 5       [RussianUkrainianWar, IStandWithPutin, istandw...
# ...                                                   ...
# 235237                                  [IStandWithPutin]
# 235238     [FuckPutin, PutinWarCriminal, IStandWithPutin]
# 235240  [USA, Putin, UkraineRussiaWar, IStandWithPutin...
# 235241                                                 []
# 235242  [evil, IStandWithPutin, IStandWithUkraine, Def...
#
#                      user_mentions  hashtags_count  user_mentions_count  \
# 0                    [sanusi90064]               3                    1
# 1                  [justsomeguycc]               2                    1
# 2                          [5thSu]               3                    1
# 3                  [Gpkumarreddy2]               2                    1
# 5                [worldobserver33]               3                    1
# ...                            ...             ...                  ...
# 235237  [de_rt_com, Mann_mit_Hund]               1                    2
# 235238                          []               3                    0
# 235240           [KremlinRussia_E]               6                    1
# 235241                [eleven45pm]               0                    1
# 235242                          []               4                    0
#
#         sentiment_score sentiment
# 0              0.581710   Neutral
# 1              0.834725  Positive
# 2              0.947319  Positive
# 3              0.554189   Neutral
# 5              0.799398  Positive
# ...                 ...       ...
# 235237         0.468949   Neutral
# 235238         0.555652   Neutral
# 235240         0.735688  Positive
# 235241         0.593956   Neutral
# 235242         0.703507  Positive
#
# [225359 rows x 14 columns]

# %% [markdown]
# # Length of Time Between Tweeting

# %%
dfTime=client_tweets.sort_values(['author_id','created_at'],ascending=True).groupby('author_id').head(200)
dfTime['diff'] =   dfTime["created_at"] - dfTime['created_at'].shift()
dfTime['match'] = dfTime.author_id.eq(dfTime.author_id.shift())
dfTime.loc[dfTime['match'] ==False , 'diff'] = None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/computation/expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [142], in <cell line: 2>()
#       1 dfTime=client_tweets.sort_values(['author_id','created_at'],ascending=True).groupby('author_id').head(200)
# ----> 2 dfTime['diff'] =   dfTime["created_at"] - dfTime['created_at'].shift()
#       3 dfTime['match'] = dfTime.author_id.eq(dfTime.author_id.shift())
#       4 dfTime.loc[dfTime['match'] ==False , 'diff'] = None
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/arraylike.py:108, in OpsMixin.__sub__(self, other)
#     106 @unpack_zerodim_and_defer("__sub__")
#     107 def __sub__(self, other):
# --> 108     return self._arith_method(other, operator.sub)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py:5639, in Series._arith_method(self, other, op)
#    5637 def _arith_method(self, other, op):
#    5638     self, other = ops.align_method_SERIES(self, other)
# -> 5639     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/base.py:1295, in IndexOpsMixin._arith_method(self, other, op)
#    1292 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1294 with np.errstate(all="ignore"):
# -> 1295     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1297 return self._construct_result(result, name=res_name)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:222, in arithmetic_op(left, right, op)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#     220     _bool_arith_check(op, left, right)
# --> 222     res_values = _na_arithmetic_op(left, right, op)
#     224 return res_values
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:170, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 except TypeError:
#     165     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     166         # For object dtype, fallback to a masked operation (only operating
#     167         #  on the non-missing values)
#     168         # Don't do this for comparisons, as that will handle complex numbers
#     169         #  incorrectly, see GH#32047
# --> 170         result = _masked_arith_op(left, right, op)
#     171     else:
#     172         raise
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:108, in _masked_arith_op(x, y, op)
#     106     # See GH#5284, GH#5035, GH#19448 for historical reference
#     107     if mask.any():
# --> 108         result[mask] = op(xrav[mask], yrav[mask])
#     110 else:
#     111     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
dfTime['diff'] = dfTime['diff'].fillna(0)
dfTime= dfTime.groupby(['author_id'])['diff'].mean().to_frame()
dfTime.reset_index(inplace=True)
dfTime

# %% [markdown]
# # Getting Tweet Similarity and Lexical Diversity

# %%
lemmer = nltk.stem.WordNetLemmatizer()
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)
def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))

# %%
nltk.download('punkt')
train_text = pd.read_csv("train_text.csv")
TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words="english")
TfidfVec.fit(train_text)

# %%
def cos_similarity(textlist):
    if textlist == []:
        return 0
    else:
        tfidf = TfidfVec.transform(textlist)
        return (tfidf * tfidf.T).toarray()

# %%
def token_type_ratio(string):
    string = re.sub(r'[^\w]', ' ', string)
    string = string.lower()
    tokens = nltk.word_tokenize(string)
    types = nltk.Counter(tokens)
    if tokens == []:
        return 0
    else:
        return (len(types)/len(tokens))*100

# %%
def average(array):
    average = []
    for i in range(len(array)):
        for j in range(len(array)):
            if i != j:
                average.append(j)
    if len(average) == 0:
        return 0
    else:
        return sum(average)/len(average)

# %%
users = puretext["author_id"].unique().tolist()

# %%
sim_dict = {}
count=0
for a_id in tqdm(users):
    if(count <=126000):
        tweets = puretext[puretext["author_id"]==a_id].text.tolist()
        sim = cos_similarity(tweets)
        sim_dict[a_id] = average(sim)
        count+=1
df_sim = pd.DataFrame(sim_dict.items(), columns=["author_id", "tweet_similarity"])

# %%
ttr_dict = {}

count=0
for a_id in tqdm(users):
    if(count <=126000):
        count+=1
        tweets = puretext[puretext["author_id"]==a_id].text.tolist()
        ttrs = [token_type_ratio(tweet) for tweet in tweets]
        if ttrs == []:
            ttr_dic[a_id] = 0
        else:
            ttr_dict[a_id] = sum(ttrs)/len(ttrs)
df_ttr = pd.DataFrame(ttr_dict.items(), columns=["author_id", "lexical_diversity"])

# %%
df_sent = data.groupby("author_id")["sentiment_score"].mean().to_frame()
df_sent.reset_index(inplace=True)
df_sent.columns = ["author_id","sentiment"]

# %%
new_data = pd.merge(df_sim, df_ttr, on="author_id")
new_data

# %%
new_data = pd.merge(new_data, df_sent, on="author_id")
new_data

# %%
new_data.to_csv(OUTPUT_LABELS, index=False)

# %% [markdown]
# # Profile Included Data

# %%
client_users

# %% [markdown]
# ### Follower Following Ratio

# %%
client_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93485 entries, 0 to 93484
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            93485 non-null  int64
#  1   created_at       93485 non-null  object
#  2   description      73011 non-null  object
#  3   id               93485 non-null  object
#  4   location         43216 non-null  object
#  5   name             93479 non-null  object
#  6   followers_count  93485 non-null  int64
#  7   following_count  93485 non-null  int64
#  8   listed_count     93485 non-null  int64
#  9   url              13204 non-null  object
#  10  username         93485 non-null  object
#  11  verified         93485 non-null  bool
#  12  tweet_count      93485 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 9.4+ MB

# %%
dfFF = client_users.copy()
dfFF=dfFF[pd.to_numeric(dfFF['following_count'], errors='coerce').notnull()]
dfFF=dfFF[pd.to_numeric(dfFF['following_count'], errors='coerce').notnull()]


dfFF['followers_count'] = dfFF['followers_count'].astype('Int64')
dfFF['following_count'] = dfFF['following_count'].astype('Int64')

# dfUsers['followers_count'] = dfUsers['followers_count'].fillna(0)
# dfUsers['following_count'] = dfUsers['following_count'].fillna(0)
# dfUsers['followers_count']=dfUsers[pd.to_numeric(dfUsers['followers_count'], errors='coerce').notnull()]
# dfUsers['following_count']=dfUsers[pd.to_numeric(dfUsers['following_count'], errors='coerce').notnull()]


client_users['f/f']=dfFF['followers_count']/dfFF['following_count']

# %%
dfFF
# Out:
#         index                 created_at  \
# 0           0  2021-08-28 19:10:25+00:00
# 1           1  2020-11-10 21:14:01+00:00
# 2           2  2010-09-08 00:20:35+00:00
# 3           3  2022-03-07 00:06:01+00:00
# 4           4  2021-02-03 18:10:48+00:00
# ...       ...                        ...
# 93480  235226  2021-02-18 08:38:41+00:00
# 93481  235227  2012-07-08 01:47:01+00:00
# 93482  235228  2022-02-01 04:15:12+00:00
# 93483  235235  2017-06-24 08:33:00+00:00
# 93484  235242  2011-02-11 00:59:16+00:00
#
#                                              description               id  \
# 0                                      አለማወቁን ያወቀ አዋቂ ነው  MustafiMohamme1
# 1      🇮🇹 Pronouns: Screw SJWs/Screw Puritans\n\nAlte...        CrowYusuf
# 2      Из дворян...\nИз крестьян...\nИз рабочих...\nИ...        alendales
# 3      Just another russian bot... maybe, hard to tel...     Shandaren123
# 4                                               politics    Betty69319283
# ...                                                  ...              ...
# 93480  Anti-social\nMechanical engineering (Trailers)...       DoumDoum19
# 93481  ذندگی کے دو ہی اصول  ☝🏻الله اور ان کا۔ رسول  ص...      XtasyRehman
# 93482                                                NaN      BinduHamal3
# 93483                                                NaN  RomeoMakgaleme1
# 93484  I’d love to design a magnificent book from you...      BabingtonCo
#
#             location                                              name  \
# 0                NaN                   Mustafi MohammedAmin 🇪🇹🇪🇷🇩🇯🇸🇴🇰🇪
# 1                NaN  Yusuf-Pronouns: No Puritans/No SJWs #KenAkamatsu
# 2                NaN                                 Александр Шаталов
# 3                NaN                                         Shandaren
# 4                NaN                                       BettyTerefe
# ...              ...                                               ...
# 93480            NaN                                         Doum_Doum
# 93481  United States                                           HRehman
# 93482            NaN                                       Bindu Hamal
# 93483   South Africa                                 Romeo Makgalemela
# 93484  United States                                      Babington.Co
#
#        followers_count  following_count  listed_count                   url  \
# 0                   56              137             0                   NaN
# 1                   59              126             1                   NaN
# 2                 1143              214            18                   NaN
# 3                   23               17             0                   NaN
# 4                 3150             1229             3                   NaN
# ...                ...              ...           ...                   ...
# 93480               72               45             0                   NaN
# 93481              196              459             0                   NaN
# 93482                1                9             0                   NaN
# 93483               12               81             0                   NaN
# 93484             1974             1853            62  https://Babington.Co
#
#               username  verified  tweet_count
# 0      MustafiMohamme1     False            1
# 1            CrowYusuf     False            8
# 2            alendales     False            1
# 3         Shandaren123     False            8
# 4        Betty69319283     False            1
# ...                ...       ...          ...
# 93480       DoumDoum19     False            1
# 93481      XtasyRehman     False            1
# 93482      BinduHamal3     False            1
# 93483  RomeoMakgaleme1     False            1
# 93484      BabingtonCo     False            1
#
# [93485 rows x 13 columns]

# %% [markdown]
# ### Listed Count / Tweet Count

# %%
client_users['l/t']= client_users['listed_count'].astype('int64')/client_users['tweet_count'].astype('int64')

# %% [markdown]
# ### UserName / Name Similarity

# %%
client_users['name'] = client_users['name'].str.replace(" ","")
client_users["name"] = client_users["name"].str.lower()
client_users["username"] = client_users["username"].str.lower()

client_users['n/u']= client_users.apply(lambda x: difflib.SequenceMatcher(None, str(x['name']), str(x['username'])).ratio(), axis=1)

# %% [markdown]
# ### Tweets And Account age

# %%
dfProfileTA = client_users.copy()

# %%
dfProfileTA
# Out:
#         index                 created_at  \
# 0           0  2021-08-28 19:10:25+00:00
# 1           1  2020-11-10 21:14:01+00:00
# 2           2  2010-09-08 00:20:35+00:00
# 3           3  2022-03-07 00:06:01+00:00
# 4           4  2021-02-03 18:10:48+00:00
# ...       ...                        ...
# 93480  235226  2021-02-18 08:38:41+00:00
# 93481  235227  2012-07-08 01:47:01+00:00
# 93482  235228  2022-02-01 04:15:12+00:00
# 93483  235235  2017-06-24 08:33:00+00:00
# 93484  235242  2011-02-11 00:59:16+00:00
#
#                                              description               id  \
# 0                                      አለማወቁን ያወቀ አዋቂ ነው  MustafiMohamme1
# 1      🇮🇹 Pronouns: Screw SJWs/Screw Puritans\n\nAlte...        CrowYusuf
# 2      Из дворян...\nИз крестьян...\nИз рабочих...\nИ...        alendales
# 3      Just another russian bot... maybe, hard to tel...     Shandaren123
# 4                                               politics    Betty69319283
# ...                                                  ...              ...
# 93480  Anti-social\nMechanical engineering (Trailers)...       DoumDoum19
# 93481  ذندگی کے دو ہی اصول  ☝🏻الله اور ان کا۔ رسول  ص...      XtasyRehman
# 93482                                                NaN      BinduHamal3
# 93483                                                NaN  RomeoMakgaleme1
# 93484  I’d love to design a magnificent book from you...      BabingtonCo
#
#             location                                          name  \
# 0                NaN                 mustafimohammedamin🇪🇹🇪🇷🇩🇯🇸🇴🇰🇪
# 1                NaN  yusuf-pronouns:nopuritans/nosjws#kenakamatsu
# 2                NaN                              александршаталов
# 3                NaN                                     shandaren
# 4                NaN                                   bettyterefe
# ...              ...                                           ...
# 93480            NaN                                     doum_doum
# 93481  United States                                       hrehman
# 93482            NaN                                    binduhamal
# 93483   South Africa                              romeomakgalemela
# 93484  United States                                  babington.co
#
#        followers_count  following_count  listed_count                   url  \
# 0                   56              137             0                   NaN
# 1                   59              126             1                   NaN
# 2                 1143              214            18                   NaN
# 3                   23               17             0                   NaN
# 4                 3150             1229             3                   NaN
# ...                ...              ...           ...                   ...
# 93480               72               45             0                   NaN
# 93481              196              459             0                   NaN
# 93482                1                9             0                   NaN
# 93483               12               81             0                   NaN
# 93484             1974             1853            62  https://Babington.Co
#
#               username  verified  tweet_count       f/f     l/t       n/u
# 0      mustafimohamme1     False            1  0.408759   0.000  0.636364
# 1            crowyusuf     False            8  0.468254   0.125  0.188679
# 2            alendales     False            1  5.341121  18.000  0.000000
# 3         shandaren123     False            8  1.352941   0.000  0.857143
# 4        betty69319283     False            1  2.563059   3.000  0.416667
# ...                ...       ...          ...       ...     ...       ...
# 93480       doumdoum19     False            1       1.6   0.000  0.842105
# 93481      xtasyrehman     False            1  0.427015   0.000  0.666667
# 93482      binduhamal3     False            1  0.111111   0.000  0.952381
# 93483  romeomakgaleme1     False            1  0.148148   0.000  0.903226
# 93484      babingtonco     False            1    1.0653  62.000  0.956522
#
# [93485 rows x 16 columns]

# %%
dfProfileTA.sort_values('tweet_count')
my_date = 1658244252
dfProfileTA['created_at']=dfProfileTA['created_at'].astype('datetime64')
dfProfileTA['DateDiff']=dfProfileTA['created_at'].apply(lambda x:x.tz_localize(None))
dfProfileTA['DateDiff']=dfProfileTA['DateDiff'].apply(lambda x:x.timestamp())

# %%
dfProfileTA['DateDiff']=(my_date-dfProfileTA['DateDiff'])/dfProfileTA['tweet_count']

# %%
dfProfileTA
# Out:
#         index          created_at  \
# 0           0 2021-08-28 19:10:25
# 1           1 2020-11-10 21:14:01
# 2           2 2010-09-08 00:20:35
# 3           3 2022-03-07 00:06:01
# 4           4 2021-02-03 18:10:48
# ...       ...                 ...
# 93480  235226 2021-02-18 08:38:41
# 93481  235227 2012-07-08 01:47:01
# 93482  235228 2022-02-01 04:15:12
# 93483  235235 2017-06-24 08:33:00
# 93484  235242 2011-02-11 00:59:16
#
#                                              description               id  \
# 0                                      አለማወቁን ያወቀ አዋቂ ነው  MustafiMohamme1
# 1      🇮🇹 Pronouns: Screw SJWs/Screw Puritans\n\nAlte...        CrowYusuf
# 2      Из дворян...\nИз крестьян...\nИз рабочих...\nИ...        alendales
# 3      Just another russian bot... maybe, hard to tel...     Shandaren123
# 4                                               politics    Betty69319283
# ...                                                  ...              ...
# 93480  Anti-social\nMechanical engineering (Trailers)...       DoumDoum19
# 93481  ذندگی کے دو ہی اصول  ☝🏻الله اور ان کا۔ رسول  ص...      XtasyRehman
# 93482                                                NaN      BinduHamal3
# 93483                                                NaN  RomeoMakgaleme1
# 93484  I’d love to design a magnificent book from you...      BabingtonCo
#
#             location                                          name  \
# 0                NaN                 mustafimohammedamin🇪🇹🇪🇷🇩🇯🇸🇴🇰🇪
# 1                NaN  yusuf-pronouns:nopuritans/nosjws#kenakamatsu
# 2                NaN                              александршаталов
# 3                NaN                                     shandaren
# 4                NaN                                   bettyterefe
# ...              ...                                           ...
# 93480            NaN                                     doum_doum
# 93481  United States                                       hrehman
# 93482            NaN                                    binduhamal
# 93483   South Africa                              romeomakgalemela
# 93484  United States                                  babington.co
#
#        followers_count  following_count  listed_count                   url  \
# 0                   56              137             0                   NaN
# 1                   59              126             1                   NaN
# 2                 1143              214            18                   NaN
# 3                   23               17             0                   NaN
# 4                 3150             1229             3                   NaN
# ...                ...              ...           ...                   ...
# 93480               72               45             0                   NaN
# 93481              196              459             0                   NaN
# 93482                1                9             0                   NaN
# 93483               12               81             0                   NaN
# 93484             1974             1853            62  https://Babington.Co
#
#               username  verified  tweet_count       f/f     l/t       n/u  \
# 0      mustafimohamme1     False            1  0.408759   0.000  0.636364
# 1            crowyusuf     False            8  0.468254   0.125  0.188679
# 2            alendales     False            1  5.341121  18.000  0.000000
# 3         shandaren123     False            8  1.352941   0.000  0.857143
# 4        betty69319283     False            1  2.563059   3.000  0.416667
# ...                ...       ...          ...       ...     ...       ...
# 93480       doumdoum19     False            1       1.6   0.000  0.842105
# 93481      xtasyrehman     False            1  0.427015   0.000  0.666667
# 93482      binduhamal3     False            1  0.111111   0.000  0.952381
# 93483  romeomakgaleme1     False            1  0.148148   0.000  0.903226
# 93484      babingtonco     False            1    1.0653  62.000  0.956522
#
#            DateDiff
# 0      2.806643e+07
# 1      6.650176e+06
# 2      3.743390e+08
# 3      1.454086e+06
# 4      4.586840e+07
# ...             ...
# 93480  4.460673e+07
# 93481  3.165322e+08
# 93482  1.455534e+07
# 93483  1.599511e+08
# 93484  3.608583e+08
#
# [93485 rows x 17 columns]

# %%
#### MERGE EVERYTHING HERE
FullData= pd.merge(dfProfileTA, new_data, how = 'inner', right_on=['author_id'],left_on=['id'])
FullData= pd.merge(FullData, dfTime, how = 'inner', right_on=['author_id'],left_on=['id'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [153], in <cell line: 2>()
#       1 #### MERGE EVERYTHING HERE
# ----> 2 FullData= pd.merge(dfProfileTA, )
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %% [markdown]
# # Model Predictions

# %%
with open("model.pkl", "rb") as f:
    rf = pickle.load(f)

# %%
predictions = rf.predict(X=FullData.values)

###Add Lables

# %%
predictionsM= FullData.merge(predictions,  how = 'Inner', right_on=[''])
predictionsM= predictionsM.drop(columns=['True_Label', 'verified','In_degree','Out_degre','Degree','batch','n/u'])
g = sns.pairplot(dfP, hue='Predicted_Label',corner='True')

# %%
# pyvis_nt.inherit_edge_colors(True)
# test = pd.read_csv('/Users/pometry/Desktop/sentiments1.csv')
pyvis_nt = Network('900px', '1400px', directed = True)
for index, row in predictions.iterrows():
    if row["Label_Source"] == "bot":
        pyvis_nt.add_node(row["SourceID"],  shape='image', image ="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGZM6dmn0zwPv0E6CYfGve08tCFQvRHt9j9g&usqp=CAU")
    if row["Label_Source"] == "human":
        pyvis_nt.add_node(row["SourceID"], shape='image', image ="https://i0.wp.com/caravetclinic.com/wp-content/uploads/2016/07/person-icon-blue.png?ssl=1")

    if row["Label_Target"] == "bot":
        pyvis_nt.add_node(row["TargetID_x"],  shape='image', image ="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGZM6dmn0zwPv0E6CYfGve08tCFQvRHt9j9g&usqp=CAU")
    if row["Label_Target"] == "human":
        pyvis_nt.add_node(row["TargetID_x"], shape='image', image ="https://i0.wp.com/caravetclinic.com/wp-content/uploads/2016/07/person-icon-blue.png?ssl=1")
        
        
        
    if row["sentiment"] == "Positive":
        pyvis_nt.add_edge(row["SourceID"], row["TargetID_x"], color='green', width=4)
    elif row["sentiment"] == "Neutral":
        pyvis_nt.add_edge(row["SourceID"], row["TargetID_x"], color='black', width=1)
    else: 
        pyvis_nt.add_edge(row["SourceID"], row["TargetID_x"], color='red', width=6)


        

    
    
pyvis_nt.toggle_physics(True)
pyvis_nt.set_edge_smooth('smooth')
pyvis_nt.show_buttons()
pyvis_nt.show('nx.html')
